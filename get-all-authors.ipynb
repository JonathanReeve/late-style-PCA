# %%
import pandas as pd
from nltk.metrics import edit_distance, fractional_presence, jaccard_distance
import re

# %%
re.search('Volume\s[0-9]', 'Shakespeare Volume 1')
# Out:
# <_sre.SRE_Match object; span=(12, 20), match='Volume 1'>

# %%
database = 'sqlite:////home/jon/Code/gitenberg-scrape/pg-text-7.db'

# %%
query = """select author, authoryearofbirth, authoryearofdeath, count(1) as books 
           from meta 
           where LCC like "%PR%" and languages like "%en%" 
           group by author having books > 10"""
authorList = pd.read_sql(query, database)

# %%
droplist = []
for i, row in authorList.iterrows():
    author = row.author
    if len(author) < 1: 
        droplist.append(i)
#     if 'Anonymous' in author:
#         droplist.append(i)
authorList = authorList.drop(droplist)

# %%
authorList.sort_values('books', ascending=False)
# Out:
#                                        author authoryearofbirth  \
# 83        Lytton, Edward Bulwer Lytton, Baron              1803
# 115                      Shakespeare, William              1564
# 68             Jacobs, W. W. (William Wymark)              1863
# 92                           Meredith, George              1828
# 119                   Stevenson, Robert Louis              1850
# 40                           Dickens, Charles              1812
# 126                         Trollope, Anthony              1815
# 79                          Le Queux, William              1864
# 113                             Scott, Walter              1771
# 43                        Doyle, Arthur Conan              1859
# 103  Oppenheim, E. Phillips (Edward Phillips)              1866
# 80                       Lever, Charles James              1806
# 84                          MacDonald, George              1824
# 51                      Fenn, George Manville              1831
# 54                           Galsworthy, John              1867
# 58            Haggard, H. Rider (Henry Rider)              1856
# 69   James, G. P. R. (George Payne Rainsford)
# 140      Yonge, Charlotte M. (Charlotte Mary)              1823
# 74                           Kipling, Rudyard              1865
# 60               Henty, G. A. (George Alfred)              1832
# 13                           Bindloss, Harold              1866
# 116                             Shaw, Bernard              1856
# 88                         Marryat, Frederick              1792
# 132             Wells, H. G. (Herbert George)              1866
# 33                             Conrad, Joseph              1857
# 136       Wodehouse, P. G. (Pelham Grenville)              1881
# 9                                Becke, Louis              1855
# 105                     Quiller-Couch, Arthur              1863
# 32                            Collins, Wilkie              1824
# 19                             Borrow, George              1803
# ..                                        ...               ...
# 61                           Hewlett, Maurice              1861
# 108                        Richardson, Samuel              1689
# 100                    Murray, David Christie              1847
# 82                      Lowndes, Marie Belloc              1868
# 114                    Sedgwick, Anne Douglas              1873
# 14                      Birmingham, George A.              1865
# 91    Maugham, W. Somerset (William Somerset)              1874
# 110                              Ruskin, John              1819
# 96                      Mitford, Mary Russell              1787
# 5                                Austen, Jane              1775
# 34                             Corelli, Marie              1855
# 99                              Mundy, Talbot              1879
# 106                            Reade, Charles              1814
# 85                         MacKenzie, Compton              1883
# 24                             Butler, Samuel              1835
# 6                                Barr, Robert              1850
# 129                      Von Arnim, Elizabeth              1866
# 81                        Locke, William John              1863
# 25          Byron, George Gordon Byron, Baron              1788
# 50                            Farnol, Jeffery              1878
# 94              Milne, A. A. (Alan Alexander)              1882
# 87                       Marlowe, Christopher              1564
# 141                          Zangwill, Israel              1864
# 130                            Wallace, Edgar              1875
# 30                         Cholmondeley, Mary              1859
# 22                               Buchan, John              1875
# 21                        Brame, Charlotte M.              1836
# 122          Tennyson, Alfred Tennyson, Baron              1809
# 138                       Wordsworth, William              1770
# 63                            Hocking, Joseph              1860
#
#     authoryearofdeath  books
# 83               1873    209
# 115              1616    174
# 68               1943    111
# 92               1909    109
# 119              1894     78
# 40               1870     74
# 126              1882     69
# 79               1927     62
# 113              1832     57
# 43               1930     57
# 103              1946     56
# 80               1872     55
# 84               1905     54
# 51               1909     53
# 54               1933     52
# 58               1925     51
# 69               1860     49
# 140              1901     48
# 74               1936     48
# 60               1902     44
# 13               1945     42
# 116              1950     40
# 88               1848     39
# 132              1946     39
# 33               1924     38
# 136              1975     37
# 9                1913     37
# 105              1944     35
# 32               1889     34
# 19               1881     33
# ..                ...    ...
# 61               1923     14
# 108              1761     14
# 100              1907     14
# 82               1947     13
# 114              1935     13
# 14               1950     13
# 91               1965     13
# 110              1900     13
# 96               1855     13
# 5                1817     13
# 34               1924     13
# 99               1940     13
# 106              1884     13
# 85               1972     13
# 24               1902     13
# 6                1912     12
# 129              1941     12
# 81               1930     12
# 25               1824     12
# 50               1952     12
# 94               1956     12
# 87               1593     12
# 141              1926     12
# 130              1932     11
# 30               1925     11
# 22               1940     11
# 21               1884     11
# 122              1892     11
# 138              1850     11
# 63               1937     11
#
# [141 rows x 4 columns]

# %%
def toInt(numStr): 
    if len(numStr) > 0: 
        return int(numStr)
    else: 
        return None
    
def getTitles(authorRow): 
    author = authorRow.author
    dob = int(authorRow.authoryearofbirth) if len(authorRow.authoryearofbirth) > 0 else None
    dod = int(authorRow.authoryearofdeath) if len(authorRow.authoryearofdeath) > 0 else None
    query = 'select id, title, author, authoryearofbirth, authoryearofdeath, gr_pubDate from meta where author = "' + author + '" and LCC like "%PR%" and languages like "%en%"'
    df = pd.read_sql(query, database)
    df.drop_duplicates('title', keep='last', inplace=True)
    droplist = []
    for i, row in df.iterrows():
        # Remove multi-volume works, 
        # since they're usually accompanied by a complete version anyway. 
        if re.search('Volume\s[0-9]', row.title) is not None: 
            droplist.append(i)
            continue
        
        # This removes titles like "The Complete Works of...," 
        # which often contain works found elsewhere in the corpus. 
        if "Works of" in row.title:
            droplist.append(i)
            continue
        
        if len(row.gr_pubDate)>3:
            date = int(row.gr_pubDate[:4])
            # Sanity check on the date of publication. 
            # Is it before or after the author's birth/death dates? 
            if dob is not None and dod is not None:
                if date < dob or date > dod: 
                    droplist.append(i)
                    continue
        
        else:
            # Scrap those without dates for now. 
            # TODO: look these up on OpenLibrary or equivalent API
            droplist.append(i)
            continue
        
    df.drop(droplist, inplace=True)
    df['date'] = df['gr_pubDate'].apply(lambda x: int(x[:4]))
    df['authoryearofbirth'] = df['authoryearofbirth'].apply(toInt)
    df['authoryearofdeath'] = df['authoryearofdeath'].apply(toInt)
    df['age'] = df['date']-df['authoryearofbirth'] if df['date'] is not None and df['authoryearofbirth'] is not None else None
    df['yearsToDeath'] = df['authoryearofdeath']-df['date']
    return df

# %%
getTitles(authorList.loc[91])
# Out:
#          id                                              title  \
# 0     222.0                              The Moon and Sixpence
# 1     351.0                                   Of Human Bondage
# 3   16517.0                                    Liza of Lambeth
# 4   26854.0  The Trembling of a Leaf: Little Stories of the...
# 8   34860.0               East of Suez: A Play in Seven Scenes
# 12  42395.0                 The Circle: A Comedy in Three Acts
#
#                                      author  authoryearofbirth  \
# 0   Maugham, W. Somerset (William Somerset)               1874
# 1   Maugham, W. Somerset (William Somerset)               1874
# 3   Maugham, W. Somerset (William Somerset)               1874
# 4   Maugham, W. Somerset (William Somerset)               1874
# 8   Maugham, W. Somerset (William Somerset)               1874
# 12  Maugham, W. Somerset (William Somerset)               1874
#
#     authoryearofdeath gr_pubDate  date  age  yearsToDeath
# 0                1965     1919--  1919   45            46
# 1                1965     1915--  1915   41            50
# 3                1965     1897--  1897   23            68
# 4                1965     1921--  1921   47            44
# 8                1965   1922-1-1  1922   48            43
# 12               1965     1921--  1921   47            44

# %%
authorTitlesDict = {authorRow.author: getTitles(authorRow)
                    for i, authorRow in authorList.iterrows() 
                    if len(getTitles(authorRow)) > 7}

# %%
authorTitlesDict['Shakespeare, William']
# Out:
#           id                                              title  \
# 1     1041.0                              Shakespeare's Sonnets
# 2     1045.0                                   Venus and Adonis
# 5     1102.0             The Third Part of King Henry the Sixth
# 8     1105.0                                        The Sonnets
# 15    1112.0                    The Tragedy of Romeo and Juliet
# 20    1117.0                       Second Part of King Henry IV
# 30    1127.0             The Tragedy of Othello, Moor of Venice
# 32    1129.0                             The Tragedy of Macbeth
# 41    1500.0                          King Henry VI, First Part
# 42    1501.0       History of King Henry the Sixth, Second Part
# 43    1502.0    The History of King Henry the Sixth, Third Part
# 44    1503.0                    The Tragedy of King Richard III
# 47    1506.0                                The Rape of Lucrece
# 53    1512.0             The Tragedy of King Richard the Second
# 57    1516.0                      King Henry IV, the First Part
# 59    1518.0                         King Henry IV, Second Part
# 66    1525.0                         The Phoenix and the Turtle
# 68    1527.0                   Twelfth Night; Or, What You Will
# 83    1543.0                                A Lover's Complaint
# 92    1773.0                            Two Gentlemen of Verona
# 95    1776.0                                    King Richard II
# 99    1780.0                              King Henry IV, Part 1
# 101   1782.0                              King Henry IV, Part 2
# 103   1784.0                                       King Henry V
# 107   1790.0                               Troilus and Cressida
# 121   2236.0                        The Two Gentlemen of Verona
# 122   2237.0                         The Merry Wives of Windsor
# 123   2238.0                                Measure for Measure
# 124   2239.0                               The Comedy of Errors
# 125   2240.0                             Much Ado about Nothing
# ..       ...                                                ...
# 131   2246.0                          All's Well That Ends Well
# 132   2247.0                                      Twelfth Night
# 133   2248.0                                  The Winter's Tale
# 134   2249.0                                          King John
# 135   2250.0                                         Richard II
# 136   2251.0                                   Henry IV, Part 1
# 137   2252.0                                   Henry IV, Part 2
# 138   2253.0                                            Henry V
# 139   2254.0                                   Henry VI, Part 1
# 140   2255.0                                   Henry VI, Part 2
# 141   2256.0                                   Henry VI, Part 3
# 142   2257.0                                        Richard III
# 143   2258.0                                         Henry VIII
# 144   2259.0                                         Coriolanus
# 145   2260.0                                   Titus Andronicus
# 146   2261.0                                   Romeo and Juliet
# 151  Shakespeare, William               1564               1616      1603--
# 152  Shakespeare, William               1564               1616      1603--
# 153  Shakespeare, William               1564               1616      1606--
# 154  Shakespeare, William               1564               1616      1611--
# 155  Shakespeare, William               1564               1616      1595--
# 156  Shakespeare, William               1564               1616      1603--
# 157  Shakespeare, William               1564               1616      1600--
# 158  Shakespeare, William               1564               1616      1596--
# 159  Shakespeare, William               1564               1616    1599-1-1
# 167  Shakespeare, William               1564               1616  1599-12-21
#
#      date  age  yearsToDeath
# 1    1592   28            24
# 2    1592   28            24
# 5    1591   27            25
# 8    1592   28            24
# 15   1595   31            21
# 20   1597   33            19
# 30   1603   39            13
# 32   1606   42            10
# 41   1590   26            26
# 42   1590   26            26
# 43   1591   27            25
# 44   1591   27            25
# 47   1594   30            22
# 53   1603   39            13
# 57   1597   33            19
# 59   1597   33            19
# 66   1601   37            15
# 68   1601   37            15
# 83   1609   45             7
# 92   1594   30            22
# 95   1595   31            21
# 99   1597   33            19
# 101  1597   33            19
# 103  1599   35            17
# 107  1602   38            14
# 121  1594   30            22
# 122  1597   33            19
# 123  1603   39            13
# 124  1594   30            22
# 125  1598   34            18
# ..    ...  ...           ...
# 131  1602   38            14
# 132  1601   37            15
# 133  1600   36            16
# 134  1595   31            21
# 135  1595   31            21
# 136  1597   33            19
# 137  1597   33            19
# 138  1599   35            17
# 139  1590   26            26
# 140  1590   26            26
# 141  1591   27            25
# 142  1591   27            25
# 143  1613   49             3
# 144  1605   41            11
# 145  1589   25            27
# 146  1595   31            21
# 147  1607   43             9
# 148  1599   35            17
# 149  1606   42            10
# 150  1600   36            16
# 151  1603   39            13
# 152  1603   39            13
# 153  1606   42            10
# 154  1611   47             5
# 155  1595   31            21
# 156  1603   39            13
# 157  1600   36            16
# 158  1596   32            20
# 159  1599   35            17
# 167  1599   35            17
#
# [65 rows x 9 columns]

# %%
masterList = pd.concat(authorTitlesDict.values())

# %%
masterList
# Out:
#          id                                              title  \
# 0    4340.0                             The British Barbarians
# 1    4396.0                                  The Woman Who Did
# 5    5869.0                                     Michael's Crag
# 6    6010.0                            What's Bred in the Bone
# 7    6060.0                                          Philistia
# 8   13876.0                                    The Great Taboo
# 9   18788.0                           Post-Prandial Philosophy
# 10  30970.0                           Miss Cayley's Adventures
# 13  43688.0   Wednesday the Tenth, A Tale of the South Pacific
# 0   14005.0                                 The Ladies Delight
# 1   15883.0  The London-Bawd: With Her Character and Life: ...
# 2   17083.0   Adventures of a Sixpence in Guernsey by A Native
# 3   17270.0                 The Interlude of Wealth and Health
# 4   20642.0                             The Assemble of Goddes
# 5   23390.0  The True Life of Betty Ireland: With Her Birth...
# 6   24825.0  The Ghost of Chatham; A Vision: Dedicated to t...
# 10  28521.0  The Power of Mesmerism: A Highly Erotic Narrat...
# 11  28522.0         Laura Middleton; Her Brother and her Lover
# 12  29189.0  A Letter From a Clergyman to his Friend,: with...
# 13  30254.0  The Romance of Lust: A Classic Victorian eroti...
# 15  33735.0                                    Pamela Censured
# 18  42289.0                                         Abbotsford
# 5         Anstey, F.              1856              1934      1915--  1915
# 6         Anstey, F.              1856              1934      1900--  1900
# 7         Anstey, F.              1856              1934      1893--  1893
# 8         Anstey, F.              1856              1934      1902--  1902
# ..               ...               ...               ...         ...   ...
# 3     Wallace, Edgar              1875              1932      1915--  1915
# 4     Wallace, Edgar              1875              1932      1920--  1920
# 5     Wallace, Edgar              1875              1932      1919--  1919
# 6     Wallace, Edgar              1875              1932      1918--  1918
# 7     Wallace, Edgar              1875              1932      1917--  1917
# 8     Wallace, Edgar              1875              1932      1917--  1917
# 9     Wallace, Edgar              1875              1932      1921--  1921
# 10    Wallace, Edgar              1875              1932      1911--  1911
# 1       Wilde, Oscar              1854              1900      1898--  1898
# 3       Wilde, Oscar              1854              1900      1879--  1879
# 4       Wilde, Oscar              1854              1900      1893--  1893
# 6       Wilde, Oscar              1854              1900      1894--  1894
# 7       Wilde, Oscar              1854              1900      1891--  1891
# 9       Wilde, Oscar              1854              1900    1893-4-1  1893
# 11      Wilde, Oscar              1854              1900      1888--  1888
# 17      Wilde, Oscar              1854              1900      1900--  1900
# 22      Wilde, Oscar              1854              1900   1887-5-29  1887
# 23      Wilde, Oscar              1854              1900      1894--  1894
# 24      Wilde, Oscar              1854              1900      1880--  1880
# 25      Wilde, Oscar              1854              1900      1891--  1891
# 26      Wilde, Oscar              1854              1900      1888--  1888
# 29      Wilde, Oscar              1854              1900      1891--  1891
# 0   Zangwill, Israel              1864              1926      1896--  1896
# 2   Zangwill, Israel              1864              1926      1903--  1903
# 3   Zangwill, Israel              1864              1926      1893--  1893
# 5   Zangwill, Israel              1864              1926      1891--  1891
# 6   Zangwill, Israel              1864              1926      1907--  1907
# 7   Zangwill, Israel              1864              1926      1898--  1898
# 8   Zangwill, Israel              1864              1926      1899--  1899
# 9   Zangwill, Israel              1864              1926      1892--  1892
#
#     age yearsToDeath
# 0    47            4
# 1    47            4
# 5    45            6
# 6    43            8
# 7    36           15
# 8    43            8
# 9    46            5
# 10   51            0
# 13   42            9
# 0   NaN          NaN
# 1   NaN          NaN
# 2   NaN          NaN
# 3   NaN          NaN
# 4   NaN          NaN
# 5   NaN          NaN
# 6   NaN          NaN
# 10  NaN          NaN
# 11  NaN          NaN
# 12  NaN          NaN
# 13  NaN          NaN
# 15  NaN          NaN
# 18  NaN          NaN
# 1    41           37
# 2    26           52
# 3    36           42
# 4    27           51
# 5    59           19
# 6    44           34
# 7    37           41
# 8    46           32
# ..  ...          ...
# 3    40           17
# 4    45           12
# 5    44           13
# 6    43           14
# 7    42           15
# 8    42           15
# 9    46           11
# 10   36           21
# 1    44            2
# 3    25           21
# 4    39            7
# 6    40            6
# 7    37            9
# 9    39            7
# 11   34           12
# 17   46            0
# 22   33           13
# 23   40            6
# 24   26           20
# 25   37            9
# 26   34           12
# 29   37            9
# 0    32           30
# 2    39           23
# 3    29           33
# 5    27           35
# 6    43           19
# 7    34           28
# 8    35           27
# 9    28           34
#
# [913 rows x 9 columns]

# %%
masterList.to_csv('bibliography/everyone.csv')
